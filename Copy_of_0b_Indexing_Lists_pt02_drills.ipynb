# %% [markdown]
# <a href="https://colab.research.google.com/github/ikoghoddds-bit/Data-Science-Portfolio-C21/blob/main/Copy_of_0b_Indexing_Lists_pt02_drills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Indexing drills

# %% [markdown]
# ## Setup

# %% [markdown]
# Copy this to your drills folder for this module.

# %% [markdown]
# ## Drills

# %% [markdown]
# Below is a collection of several lists of numbers with the numbers 1, 2, and 3 embedded.  The numbers 1, 2, and 3 are always equally spaced and in order, although the order may be reversed.
#
# Your task is four-fold:
# 1. pick a variable
# 1. come up with an index syntax for the variable to extract the 1, 2, and 3.
# 1. display the following:
#     - the original variable name
#     - the original variable value
#     - the index values
#     - the result of each of the indices, which should be 1, 2, and 3, respectively
# 1. do as many as you can in 5 minutes

# %% [markdown]
# The full collection of list variables.

# %%
line_001 = [50, 50, 50, 50, 1, 2, 3, 50, 50, 50, 50, 50, 50]
line_002 = [50, 1, 2, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_003 = [50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50]
line_004 = [50, 50, 50, 50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50]
line_005 = [50, 50, 50, 50, 50, 50, 50, 50, 50, 3, 2, 1]
line_006 = [50, 50, 3, 2, 1, 50, 50, 50, 50, 50, 50, 50, 50]
line_007 = [50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50]
line_008 = [50, 50, 50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50, 50, 50]
line_009 = [50, 50, 50, 50, 50, 50, 50, 1, 2, 3, 50, 50, 50]
line_010 = [50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50]
line_011 = [50, 50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50]
line_012 = [50, 50, 50, 50, 50, 50, 50, 3, 10, 10, 10, 2, 10, 10, 10, 1, 50, 50, 50]
line_013 = [50, 50, 3, 10, 2, 10, 1, 50, 50, 50, 50, 50, 50, 50, 50]
line_014 = [50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50, 50, 50, 50]
line_015 = [50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50]
line_016 = [50, 50, 50, 50, 50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50]
line_017 = [50, 50, 50, 3, 2, 1, 50, 50, 50, 50, 50, 50, 50]
line_018 = [50, 50, 1, 2, 3, 50, 50, 50, 50, 50, 50, 50, 50]
line_019 = [50, 50, 50, 1, 2, 3, 50, 50, 50, 50, 50, 50, 50]
line_020 = [50, 50, 50, 50, 3, 2, 1, 50, 50, 50, 50, 50, 50]
line_021 = [50, 1, 10, 2, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_022 = [50, 50, 50, 50, 50, 1, 2, 3, 50, 50, 50, 50, 50]
line_023 = [50, 50, 50, 50, 50, 50, 3, 10, 10, 10, 2, 10, 10, 10, 1, 50, 50, 50, 50]
line_024 = [50, 50, 50, 50, 50, 50, 50, 50, 50, 1, 2, 3]
line_025 = [50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_026 = [1, 2, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_027 = [50, 50, 50, 50, 50, 50, 50, 3, 10, 10, 2, 10, 10, 1, 50, 50, 50]
line_028 = [50, 50, 3, 10, 10, 2, 10, 10, 1, 50, 50, 50, 50, 50, 50, 50, 50]
line_029 = [50, 50, 50, 50, 3, 10, 10, 10, 2, 10, 10, 10, 1, 50, 50, 50, 50, 50, 50]
line_030 = [50, 50, 50, 50, 50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50]
line_031 = [50, 50, 50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50, 50]
line_032 = [50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50, 50, 50, 50, 50]
line_033 = [1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_034 = [50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_035 = [50, 50, 50, 1, 10, 2, 10, 3, 50, 50, 50, 50, 50, 50, 50]
line_036 = [50, 50, 50, 50, 50, 50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50]
line_037 = [50, 50, 50, 50, 50, 50, 3, 2, 1, 50, 50, 50, 50]
line_038 = [1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_039 = [50, 50, 50, 3, 10, 10, 2, 10, 10, 1, 50, 50, 50, 50, 50, 50, 50]
line_040 = [50, 50, 50, 50, 50, 50, 50, 50, 3, 2, 1, 50, 50]
line_041 = [50, 50, 50, 50, 50, 50, 1, 2, 3, 50, 50, 50, 50]
line_042 = [50, 50, 50, 50, 50, 50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50]
line_043 = [50, 50, 50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50]
line_044 = [3, 2, 1, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_045 = [50, 50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50, 50, 50]
line_046 = [50, 50, 50, 50, 50, 50, 50, 3, 2, 1, 50, 50, 50]
line_047 = [1, 10, 2, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]
line_048 = [50, 50, 50, 50, 50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50]
line_049 = [50, 50, 50, 50, 50, 50, 50, 50, 1, 2, 3, 50, 50]
line_050 = [50, 50, 50, 50, 50, 50, 50, 50, 50, 3, 10, 10, 10, 2, 10, 10, 10, 1, 50]

# %% [markdown]
# ## Examples

# %% [markdown]
# Here's the index syntax for two of the list variables.

# %% [markdown]
# ### Example 1

# %% [markdown]
# This example uses three code cells.

# %%
print("line_001")
print(line_001)
# Out:
# line_001
# [50, 50, 50, 50, 1, 2, 3, 50, 50, 50, 50, 50, 50]

# %%
print( "1:", 4 )
print( "2:", 5 )
print( "3:", 6 )
# Out:
# 1: 4
# 2: 5
# 3: 6

# %%
print(line_001[4])
print(line_001[5])
print(line_001[6])
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Example 2

# %% [markdown]
# Here's an example in a single code cell using an f-string.

# %%
i1 = 6
i2 = 4
i3 = 2

print(f'''
  line: line_013
  values: {line_013}
  1: {i1}, {line_013[i1]}
  2: {i2}, {line_013[i2]}
  3: {i3}, {line_013[i3]}
''')
# Out:
#   line: line_013
#   values: [50, 50, 3, 10, 2, 10, 1, 50, 50, 50, 50, 50, 50, 50, 50]
#   1: 6, 1
#   2: 4, 2
#   3: 2, 3

# %% [markdown]
# ## Your turn

# %%
blah = line_001

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_001")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_001
# [50, 50, 50, 50, 1, 2, 3, 50, 50, 50, 50, 50, 50]
# 1: 4
# 2: 5
# 3: 6
# 1
# 2
# 3

# %%
blah = line_002

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_002")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_002
# [50, 1, 2, 3, 50, 50, 50, 50, 50, 50, 50, 50, 50]
# 1: 1
# 2: 2
# 3: 3
# 1
# 2
# 3

# %%
blah = line_003

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_003")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_003
# [50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50]
# 1: 3
# 2: 7
# 3: 11
# 1
# 2
# 3

# %%
blah = line_004

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_004")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_004
# [50, 50, 50, 50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50]
# 1: 8
# 2: 10
# 3: 12
# 1
# 2
# 3

# %%
blah = line_005

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_005")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_005
# [50, 50, 50, 50, 50, 50, 50, 50, 50, 3, 2, 1]
# 1: 11
# 2: 10
# 3: 9
# 1
# 2
# 3

# %%
blah = line_006

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_006")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_006
# [50, 50, 3, 2, 1, 50, 50, 50, 50, 50, 50, 50, 50]
# 1: 4
# 2: 3
# 3: 2
# 1
# 2
# 3

# %%
blah = line_007

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_007")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_007
# [50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50]
# 1: 2
# 2: 6
# 3: 10
# 1
# 2
# 3

# %%
blah = line_008

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_008")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_008
# [50, 50, 50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50, 50, 50]
# 1: 4
# 2: 7
# 3: 10
# 1
# 2
# 3

# %%
blah = line_009

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_009")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_009
# [50, 50, 50, 50, 50, 50, 50, 1, 2, 3, 50, 50, 50]
# 1: 7
# 2: 8
# 3: 9
# 1
# 2
# 3

# %%
blah = line_010

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_010")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_010
# [50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50, 50, 50, 50, 50]
# 1: 2
# 2: 5
# 3: 8
# 1
# 2
# 3

# %%
blah = line_011

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_011")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_011
# [50, 50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50]
# 1: 5
# 2: 9
# 3: 13
# 1
# 2
# 3

# %%
blah = line_012

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_012")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_012
# [50, 50, 50, 50, 50, 50, 50, 3, 10, 10, 10, 2, 10, 10, 10, 1, 50, 50, 50]
# 1: 15
# 2: 11
# 3: 7
# 1
# 2
# 3

# %%
blah = line_013

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_013")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_013
# [50, 50, 3, 10, 2, 10, 1, 50, 50, 50, 50, 50, 50, 50, 50]
# 1: 6
# 2: 4
# 3: 2
# 1
# 2
# 3

# %%
blah = line_014

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_014")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_014
# [50, 50, 50, 50, 50, 1, 10, 2, 10, 3, 50, 50, 50, 50, 50]
# 1: 5
# 2: 7
# 3: 9
# 1
# 2
# 3

# %%
blah = line_015

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_015")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_015
# [50, 50, 50, 50, 1, 10, 10, 10, 2, 10, 10, 10, 3, 50, 50, 50, 50, 50, 50]
# 1: 4
# 2: 8
# 3: 12
# 1
# 2
# 3

# %%
blah = line_016

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_016")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_016
# [50, 50, 50, 50, 50, 50, 1, 10, 10, 2, 10, 10, 3, 50, 50, 50, 50]
# 1: 6
# 2: 9
# 3: 12
# 1
# 2
# 3

# %%
blah = line_017

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_017")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print(blah[i1])
print(blah[i2])
print(blah[i3])
# Out:
# line_017
# [50, 50, 50, 3, 2, 1, 50, 50, 50, 50, 50, 50, 50]
# 1: 5
# 2: 4
# 3: 3
# 1
# 2
# 3

# %%
blah = line_017

i1 = blah.index(1)
i2 = blah.index(2)
i3 = blah.index(3)

print("line_017")
print(blah)

print( "1:", i1 )
print( "2:", i2 )
print( "3:", i3 )

print ((blah[i1]), (blah[i2]), (blah[i3]))
# Out:
# line_017
# [50, 50, 50, 3, 2, 1, 50, 50, 50, 50, 50, 50, 50]
# 1: 5
# 2: 4
# 3: 3
# 1 2 3
